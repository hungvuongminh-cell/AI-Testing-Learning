# %% [markdown]
# <a href="https://colab.research.google.com/github/hungvuongminh-cell/AI-Testing-Learning/blob/main/Phase_01/0001_A%20basic%20code%20of%20AI%20testing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google import genai
from google.colab import userdata
import time

# 1. API CONFIGURATION (New SDK Style)
api_key = userdata.get('key')
client = genai.Client(api_key=api_key)

# 2. MODEL SELECTION
# Note: Using the latest stable model
SELECTED_MODEL = 'gemini-2.5-flash'

# 3. TEST DATASET
questions = [
    "What is the capital of Vietnam?",
    "What is 1 + 1?",
    "Name a famous dish in Ho Chi Minh City"
]

print("--- STARTING TEST EXECUTION (NEW SDK) ---")

# 4. EXECUTION LOOP
for q in questions:
    try:
        # New method: models.generate_content
        response = client.models.generate_content(
            model=SELECTED_MODEL,
            contents=q
        )

        print(f"Question: {q}")
        print(f"AI Response: {response.text.strip()}")
        print("-" * 20)

        # Adding a small delay to respect free tier quotas
        time.sleep(10)

    except Exception as e:
        print(f"Error encountered: {e}")

print("--- TEST EXECUTION COMPLETED ---")
# Out:
# --- STARTING TEST EXECUTION (NEW SDK) ---
# Question: What is the capital of Vietnam?
# AI Response: The capital of Vietnam is **Hanoi**.
# --------------------
# Question: What is 1 + 1?
# AI Response: 1 + 1 = 2
# --------------------
# Question: Name a famous dish in Ho Chi Minh City
# AI Response: One of the most famous dishes in Ho Chi Minh City is **Cơm Tấm** (Broken Rice).
#
# It's a quintessential Southern Vietnamese dish featuring fragrant broken rice served with various toppings like grilled pork chop (sườn nướng), shredded pork skin (bì), steamed egg meatloaf (chả trứng), a fried egg (ốp la), and fresh vegetables, all drizzled with a sweet and savory fish sauce. You'll find it practically on every street corner.
#
# Other incredibly popular dishes include **Bánh Mì** and **Hủ Tiếu**.
# --------------------
# --- TEST EXECUTION COMPLETED ---
